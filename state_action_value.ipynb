# %%
import numpy as np
from utilsstate import *

# %%
num_state=6
num_actions=2

# %%
terminal_left_reward=100
terminal_right_reward=40
each_step_reward=0

gama=0.9

misstep_prob=0

# %%
generate_visualization(terminal_left_reward,terminal_right_reward,each_step_reward,gama,misstep_prob)
